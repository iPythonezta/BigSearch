# %%
import json
import os
import pandas as pd

# %%
metadata_cleaned = pd.read_csv("../Data/Cord 19/metadata_cleaned.csv")

# %%
map_ = pd.read_csv("../Data/PageRankCord19/references_map.csv")

# %%
map_.head()
# Out:
#                                           from_paper  \
# 0  sequence requirements for rna strand transfer ...
# 1  sequence requirements for rna strand transfer ...
# 2  sequence requirements for rna strand transfer ...
# 3  sequence requirements for rna strand transfer ...
# 4  sequence requirements for rna strand transfer ...
#
#                                             to_paper
# 0  recombination in rna viruses and in virus resi...
# 1  minimal templates directing accurate initiatio...
# 2  engineering the largest rna virus genome as an...
# 3  an in vitro system for the leaderprimed transc...
# 4  subgenomic negative strand rna function during...

# %%
# Top ranked papers by citations
map_.groupby('to_paper').count().sort_values(ascending=False, by='from_paper').head(10)
# Out:
#                                                     from_paper
# to_paper
# isolation of a novel coronavirus from a man wit...         771
# a novel coronavirus from patients with pneumoni...         729
# identification of a novel coronavirus in patien...         698
# a novel coronavirus associated with severe acut...         683
# early transmission dynamics in wuhan china of n...         680
# epidemiological and clinical characteristics of...         667
# clinical characteristics of coronavirus disease...         652
# clinical features of patients infected with nov...         647
# coronavirus as a possible cause of severe acute...         538
# a pneumonia outbreak associated with a new coro...         507

# %%
# Least cited papers
map_.groupby('to_paper').count().sort_values(ascending=True, by='from_paper').head(10)
# Out:
#                                                     from_paper
# to_paper
# the effects of prenatal exposure to predictable...           0
# hiv dementia and the basal ganglia                           0
# registrar general annual report of the registra...           0
# association between early onset parkinson s dis...           0
# synaptic density in human frontal cortexdevelop...           0
# echoes of as new yorkers try to keep calm but w...           0
# covid got ya in a childcare jam clarkmalissa an...           0
# adrenomedullary catecholamine release in the fe...           0
# human brain dopamine receptors in children and ...           0
# with americans hunkering down some wonder if co...           0

# %%
encodings_folder = '../Encodings/Research Paper Encodings/'

# %%
titles = set()
for idx, row in map_.iterrows():
    to_title = row['to_paper']
    from_title = row['from_paper']
    titles.add(to_title)
    titles.add(from_title)

# %%
titles_id = {title: id for id, title in enumerate(titles)}

# %%
with open(os.path.join(encodings_folder, 'titles_id.json'), 'w') as f:
    json.dump(titles_id, f)

# %%
id_based_map = map_.copy()
id_based_map['to_paper'] = id_based_map['to_paper'].map(titles_id)
id_based_map['from_paper'] = id_based_map['from_paper'].map(titles_id)

# %%
id_based_map.head()
# Out:
#    from_paper  to_paper
# 0      867447    634718
# 1      867447     42072
# 2      867447     67122
# 3      867447    355235
# 4      867447     12036

# %%
id_based_map[['to_paper', 'from_paper']].to_csv(os.path.join(encodings_folder, 'id_based_references_map.csv'), index=False)

# %%
len(titles)
# Out:
# 960890

# %% [markdown]
# ### Reading and Transforming Results

# %%
results_path = "..\\Page Rank Results\\citation_rank_output.csv"
citation_ranks = pd.read_csv(results_path, header=None, names=['paper_id', 'citation_rank'])

# %%
citation_ranks.head()
# Out:
#    paper_id  citation_rank
# 0    820761       0.005979
# 1    902017       0.003455
# 2    544952       0.001806
# 3    881244       0.001091
# 4     26432       0.001031

# %%
titles_id = {}
with open(os.path.join(encodings_folder, 'titles_id.json'), 'r') as f:
    titles_id = json.load(f)

id_titles = {id: title for title, id in titles_id.items()}

# %%
citation_ranks["paper_title"] = citation_ranks['paper_id'].map(id_titles)

# %%
citation_ranks.sort_values(ascending=False, by='citation_rank')
# Out:
#         paper_id  citation_rank  \
# 0         820761   5.979350e-03
# 1         902017   3.454510e-03
# 2         544952   1.806490e-03
# 3         881244   1.091290e-03
# 4          26432   1.031200e-03
# ...          ...            ...
# 341999    909756   4.701500e-07
# 342000    909757   4.701500e-07
# 342001    909758   4.701500e-07
# 342002    909759   4.701500e-07
# 960889    325775   4.701500e-07
#
#                                               paper_title
# 0       viral glycoproteins biological role and applic...
# 1            bibliography of the current world literature
# 2                                    author index volumes
# 3       spezielle arzneimitteltherapie in der schwange...
# 4                                 cumulative contents for
# ...                                                   ...
# 341999  transmigration of human cd monocytes across th...
# 342000  phase i clinical trials with three formulation...
# 342001  chlamydial persistence beyond the biphasic par...
# 342002    authors address e caui public health laboratory
# 960889                       inflammation and coagulation
#
# [960890 rows x 3 columns]

# %%
num_papers = len(citation_ranks) - 1
citation_ranks["Score"] = 0
for i in range(10):
    start_idx = int(i * 0.1 * num_papers)
    end_idx = int((i + 1) * 0.1 * num_papers)
    citation_ranks.loc[start_idx:end_idx, "Score"] = 10 - i

# %%
citation_ranks.head()
# Out:
#    paper_id  citation_rank                                        paper_title  \
# 0    820761       0.005979  viral glycoproteins biological role and applic...
# 1    902017       0.003455       bibliography of the current world literature
# 2    544952       0.001806                               author index volumes
# 3    881244       0.001091  spezielle arzneimitteltherapie in der schwange...
# 4     26432       0.001031                            cumulative contents for
#
#    Score
# 0     10
# 1     10
# 2     10
# 3     10
# 4     10

# %%
len(citation_ranks[citation_ranks["Score"] == 1])
# Out:
# 96090

# %%
len(citation_ranks[citation_ranks["Score"] == 1])
# Out:
# 96090

# %%
citation_ranks[["paper_title", "citation_rank", "Score"]].to_csv("../Page Rank Results/citation_ranks_with_scores.csv", index=False)
